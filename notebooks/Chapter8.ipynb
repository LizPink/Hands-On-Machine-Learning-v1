# %% [markdown]
# ## 8.5 动手实现多层感知机

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 导入数据集

# %%
# 导入数据集
data = np.loadtxt("../data/raw/Chapter8/xor_dataset.csv", delimiter=",")
print(f"数据集大小: {len(data)}")
print(data[:5])

# 划分训练集与测试集
ratio = 0.8
split = int(ratio*len(data))

rng = np.random.default_rng(seed=42)
data = rng.permutation(data)

x_train, y_train  = data[:split,:2], data[:split,-1].reshape((-1,1))
x_test, y_test = data[split:,:2], data[split:,-1].reshape((-1,1))

print(x_train[:5], y_train[:5])
# Out:
# 数据集大小: 1000
# [[ 1.7641  0.4002  0.    ]
#  [ 0.9787  2.2409  0.    ]
#  [ 1.8676 -0.9773  1.    ]
#  [ 0.9501 -0.1514  1.    ]
#  [-0.1032  0.4106  1.    ]]
# [[ 0.4178 -1.2402]
#  [ 0.5541 -0.6701]
#  [ 0.2466  0.608 ]
#  [-0.306  -0.4385]
#  [ 0.6915  0.6947]] [[1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]]

# %% [markdown]
# ### 定义感知机

# %%
# Out:
# tensor([[4, 5, 6]])
